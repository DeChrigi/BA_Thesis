# %%
import pandas as pd
import networkx as nx

# %%
df = pd.read_excel('./raw_data/cartel_shareholders/Aalberts.xls', sheet_name='Results_AALB-AE_4_8_12_16_')
# Out:
# ['Étoile Gestion'
#  'WestLB Mellon Asset Management Kapitalanlagegesellschaft mbH'
#  'Wealth Management Partners NV'
#  'Waddell & Reed Investment Management Company'
#  'W & W Asset Management GmbH' 'Vontobel Asset Management, Inc.'
#  'Vanguard Group, Inc.' 'VPB Finance S.A.'
#  'Universal-Investment-Gesellschaft mbH' 'Union Investment Group'
#  'Union Bancaire Privée' 'Unigestion'
#  'UBS Wealth Management AG (Switzerland)'
#  'UBS Global Asset Management (UK) Ltd.'
#  'UBS Global Asset Management (Switzerland)'
#  'Treetop Asset Management S.A.' 'Tredje AP Fonden' 'Tolsteeg NV'
#  'The Boston Company Asset Management, LLC'
#  'Templeton Investment Counsel, LLC'
#  'Templeton Asset Management Ltd. (Emerging Markets)' 'TIAA-CREF'
#  'T. Rowe Price International (UK) Ltd.' 'Swisscanto Asset Management AG'
#  'Swiss & Global Asset Management Ltd.' 'Swedbank Robur AB'
#  'Stichting Administratiekantoor KVB' 'State Street Global Advisors (US)'
# ...
