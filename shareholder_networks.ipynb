# %%
import networkx as nx
from pyvis.network import Network
import pandas as pd
import math
import matplotlib.pyplot as plt
import os

# %% [markdown]
# Read all transformed shareholder files

# %%
# Create list to hold shareholder dataframes
shareholder_dfs = []

# for each file in directory
for filename in os.listdir('./transformed_data/base/shareholders'):
    # check if file is a .xlsx file
    if filename.endswith('.xlsx'):
        # read the file into a dataframe
        df = pd.read_excel(f'./transformed_data/base/shareholders/{filename}')
        # add the dataframe to the list
        shareholder_dfs.append(df)

# print number of dataframes, should be equal to number of files -> should be 61
print(f"Number of dataframes: {len(shareholder_dfs)}")
# Out:
# Number of dataframes: 61

# %% [markdown]
# Create a graph for every year in every file

# %%
for sh_df in shareholder_dfs:
    # Get all columns with perc_os in the name
    perc_os_columns = sh_df.columns[sh_df.columns.str.contains('perc_os')]
    
    # Get the name of the company e.g. ABB (Take 0 index because we only have one company per file -> its the same for all rows)
    company_name = sh_df["company_name"][0]
    
    # Print the name of the company to see progress
    print(company_name)

    # Create a graph for each column with perc_os in the name
    for column in perc_os_columns:
        G = nx.Graph()

        for _, row in sh_df.iterrows():

            investor = row["investor_name"] # name of the investor
            company = row["company_name"] # redundant, but for clarity
            weight = row[column] # percentage ownership

            # Check if weight (perc_os) is not null
            if not pd.isna(weight):  
                G.add_node(company, type="Company") 
                G.add_node(investor, type="Investor")
                G.add_edge(investor, company, weight=weight)
        
        # Save the graph as a graphml file
        nx.write_graphml(G, f"./transformed_data/shareholder_networks/shareholder_network_{company_name}_{str.replace(column, 'perc_os_', '')}.graphml", named_key_ids=True, infer_numeric_types=True)

print("---Finished---")
# Out:
# Aalberts
# ABB
# Akzo Nobel
# Alstom SA
# Areva
# Asahi
# AU Optronics
# BAM
# Bayern
# Boliden
# British Airways
# Cathay Pacific
# Chemtura
# Chimei
# chiquita
# Chungwa
# Commerzbank
# del monte
# Dow
# Elpida
# ENI
# EON
# Exxon Mobil
# Fuji Electric
# Fujifilm
# GDF suez
# Hannstar Display
# Henkel
# hitachi ltd
# Hitachi Maxell
# ICI
# IMI PLC
# Infineon
# LG Display
# Micron
# Mitsubishi
# Mueller Industries
# Nanya Tech
# NEC
# Nippon electric glass
# Panasonic
# Pilkington
# procter gamble
# Qantas
# rautaruukki
# Repsol YPF
# samsung
# SAS AB
# Siemens
# Singapore Airlines
# SKW Stahl
# Sony
# Toshiba
# Total
# Unilever NV
# Unilever PLC
# Unipetrol
# United technologies corp
# Uralita
# Whirlpool
# Zeon
# ---Finished---

# %% [markdown]
# Calculate the herfindal-hirschmann index and the centrality metrics for each file and each year

# %%
from networkx import PowerIterationFailedConvergence


company_metrics = []

# for each graph-file in directory
for filename in os.listdir('./transformed_data/shareholder_networks/'):

    # check if file is a .graphml file
    if filename.endswith('.graphml'):

        # read the file into a graph
        G = nx.read_graphml(f'./transformed_data/shareholder_networks/{filename}')

        # get the company name from the filename
        company_name = filename.split('_')[2]

        # get the year from the filename
        year = filename.split('.')[0][-4:]
        
        print(f"Calculating metrics for {company_name} in {year}")

        # get the weights of the edges
        weights = [data['weight'] for _, _, data in G.edges(data=True)]

        # calculate the herfindahl index and round it to 2 decimal places
        herfindahl_index = round(sum([w**2 for w in weights]), 2)

        try:
            # calculate the centralities for the company node
            company_node = [n for n, d in G.nodes(data=True) if d['type'] == 'Company'][0]
            degree_centrality = nx.degree_centrality(G)[company_node]
            closeness_centrality = nx.closeness_centrality(G)[company_node]
            betweenness_centrality = nx.betweenness_centrality(G)[company_node]
            eigenvector_centrality = nx.eigenvector_centrality(G)[company_node]
            pagerank_centrality = nx.pagerank(G)[company_node]
        except IndexError:
            # if the company node is not found, set the centralities to None
            degree_centrality = None
            closeness_centrality = None
            betweenness_centrality = None
            eigenvector_centrality = None
            pagerank_centrality = None

        except PowerIterationFailedConvergence:
            # if the eigenvector centrality calculation fails, set it to None
            eigenvector_centrality = None
        
        # number of investors
        num_investors = len([n for n, d in G.nodes(data=True) if d['type'] == 'Investor'])

        # create a dictionary with the metrics
        metrics = {
            'company_name': company_name,
            'year': year,
            'num_investors': num_investors,
            'herfindahl_index': herfindahl_index,
            'degree_centrality': degree_centrality,
            'closeness_centrality': closeness_centrality,
            'betweenness_centrality': betweenness_centrality,
            'eigenvector_centrality': eigenvector_centrality,
            'pagerank_centrality': pagerank_centrality
        }

        # append the metrics to the list
        company_metrics.append(metrics)

    
# create a dataframe from the list of metrics
company_metrics_df = pd.DataFrame(company_metrics)

# save the dataframe to a xlsx file
company_metrics_df.to_excel('./transformed_data/shareholder_data/company_metrics.xlsx', index=False)
# Out:
# Calculating metrics for Aalberts in 1997
# Calculating metrics for Aalberts in 1998
# Calculating metrics for Aalberts in 1999
# Calculating metrics for Aalberts in 2000
# Calculating metrics for Aalberts in 2001
# Calculating metrics for Aalberts in 2002
# Calculating metrics for Aalberts in 2003
# Calculating metrics for Aalberts in 2004
# Calculating metrics for Aalberts in 2005
# Calculating metrics for Aalberts in 2006
# Calculating metrics for Aalberts in 2007
# Calculating metrics for Aalberts in 2008
# Calculating metrics for Aalberts in 2009
# Calculating metrics for Aalberts in 2010
# Calculating metrics for Aalberts in 2011
# Calculating metrics for ABB in 1997
# Calculating metrics for ABB in 1998
# Calculating metrics for ABB in 1999
# Calculating metrics for ABB in 2000
# Calculating metrics for ABB in 2001
# Calculating metrics for ABB in 2002
# Calculating metrics for ABB in 2003
# Calculating metrics for ABB in 2004
# Calculating metrics for ABB in 2005
# Calculating metrics for ABB in 2006
# Calculating metrics for ABB in 2007
# Calculating metrics for ABB in 2008
# Calculating metrics for ABB in 2009
# Calculating metrics for ABB in 2010
# Calculating metrics for ABB in 2011
# Calculating metrics for Akzo Nobel in 1997
# Calculating metrics for Akzo Nobel in 1998
# Calculating metrics for Akzo Nobel in 1999
# Calculating metrics for Akzo Nobel in 2000
# Calculating metrics for Akzo Nobel in 2001
# Calculating metrics for Akzo Nobel in 2002
# Calculating metrics for Akzo Nobel in 2003
# Calculating metrics for Akzo Nobel in 2004
# Calculating metrics for Akzo Nobel in 2005
# Calculating metrics for Akzo Nobel in 2006
# Calculating metrics for Akzo Nobel in 2007
# Calculating metrics for Akzo Nobel in 2008
# Calculating metrics for Akzo Nobel in 2009
# Calculating metrics for Akzo Nobel in 2010
# Calculating metrics for Akzo Nobel in 2011
# Calculating metrics for Alstom SA in 1997
# Calculating metrics for Alstom SA in 1998
# Calculating metrics for Alstom SA in 1999
# Calculating metrics for Alstom SA in 2000
# Calculating metrics for Alstom SA in 2001
# Calculating metrics for Alstom SA in 2002
# Calculating metrics for Alstom SA in 2003
# Calculating metrics for Alstom SA in 2004
# Calculating metrics for Alstom SA in 2005
# Calculating metrics for Alstom SA in 2006
# Calculating metrics for Alstom SA in 2007
# Calculating metrics for Alstom SA in 2008
# Calculating metrics for Alstom SA in 2009
# Calculating metrics for Alstom SA in 2010
# Calculating metrics for Alstom SA in 2011
# Calculating metrics for Areva in 1997
# Calculating metrics for Areva in 1998
# Calculating metrics for Areva in 1999
# Calculating metrics for Areva in 2000
# Calculating metrics for Areva in 2001
# Calculating metrics for Areva in 2002
# Calculating metrics for Areva in 2003
# Calculating metrics for Areva in 2004
# Calculating metrics for Areva in 2005
# Calculating metrics for Areva in 2006
# Calculating metrics for Areva in 2007
# Calculating metrics for Areva in 2008
# Calculating metrics for Areva in 2009
# Calculating metrics for Areva in 2010
# Calculating metrics for Areva in 2011
# Calculating metrics for Asahi in 1997
# Calculating metrics for Asahi in 1998
# Calculating metrics for Asahi in 1999
# Calculating metrics for Asahi in 2000
# Calculating metrics for Asahi in 2001
# Calculating metrics for Asahi in 2002
# Calculating metrics for Asahi in 2003
# Calculating metrics for Asahi in 2004
# Calculating metrics for Asahi in 2005
# Calculating metrics for Asahi in 2006
# Calculating metrics for Asahi in 2007
# Calculating metrics for Asahi in 2008
# Calculating metrics for Asahi in 2009
# Calculating metrics for Asahi in 2010
# Calculating metrics for Asahi in 2011
# Calculating metrics for AU Optronics in 1997
# Calculating metrics for AU Optronics in 1998
# Calculating metrics for AU Optronics in 1999
# Calculating metrics for AU Optronics in 2000
# Calculating metrics for AU Optronics in 2001
# Calculating metrics for AU Optronics in 2002
# Calculating metrics for AU Optronics in 2003
# Calculating metrics for AU Optronics in 2004
# Calculating metrics for AU Optronics in 2005
# Calculating metrics for AU Optronics in 2006
# Calculating metrics for AU Optronics in 2007
# Calculating metrics for AU Optronics in 2008
# Calculating metrics for AU Optronics in 2009
# Calculating metrics for AU Optronics in 2010
# Calculating metrics for AU Optronics in 2011
# Calculating metrics for BAM in 1997
# Calculating metrics for BAM in 1998
# Calculating metrics for BAM in 1999
# Calculating metrics for BAM in 2000
# Calculating metrics for BAM in 2001
# Calculating metrics for BAM in 2002
# Calculating metrics for BAM in 2003
# Calculating metrics for BAM in 2004
# Calculating metrics for BAM in 2005
# Calculating metrics for BAM in 2006
# Calculating metrics for BAM in 2007
# Calculating metrics for BAM in 2008
# Calculating metrics for BAM in 2009
# Calculating metrics for BAM in 2010
# Calculating metrics for BAM in 2011
# Calculating metrics for Bayern in 1997
# Calculating metrics for Bayern in 1998
# Calculating metrics for Bayern in 1999
# Calculating metrics for Bayern in 2000
# Calculating metrics for Bayern in 2001
# Calculating metrics for Bayern in 2002
# Calculating metrics for Bayern in 2003
# Calculating metrics for Bayern in 2004
# Calculating metrics for Bayern in 2005
# Calculating metrics for Bayern in 2006
# Calculating metrics for Bayern in 2007
# Calculating metrics for Bayern in 2008
# Calculating metrics for Bayern in 2009
# Calculating metrics for Bayern in 2010
# Calculating metrics for Bayern in 2011
# Calculating metrics for Boliden in 1997
# Calculating metrics for Boliden in 1998
# Calculating metrics for Boliden in 1999
# Calculating metrics for Boliden in 2000
# Calculating metrics for Boliden in 2001
# Calculating metrics for Boliden in 2002
# Calculating metrics for Boliden in 2003
# Calculating metrics for Boliden in 2004
# Calculating metrics for Boliden in 2005
# Calculating metrics for Boliden in 2006
# Calculating metrics for Boliden in 2007
# Calculating metrics for Boliden in 2008
# Calculating metrics for Boliden in 2009
# Calculating metrics for Boliden in 2010
# Calculating metrics for Boliden in 2011
# Calculating metrics for British Airways in 1997
# Calculating metrics for British Airways in 1998
# Calculating metrics for British Airways in 1999
# Calculating metrics for British Airways in 2000
# Calculating metrics for British Airways in 2001
# Calculating metrics for British Airways in 2002
# Calculating metrics for British Airways in 2003
# Calculating metrics for British Airways in 2004
# Calculating metrics for British Airways in 2005
# Calculating metrics for British Airways in 2006
# Calculating metrics for British Airways in 2007
# Calculating metrics for British Airways in 2008
# Calculating metrics for British Airways in 2009
# Calculating metrics for British Airways in 2010
# Calculating metrics for British Airways in 2011
# Calculating metrics for Cathay Pacific in 1997
# Calculating metrics for Cathay Pacific in 1998
# Calculating metrics for Cathay Pacific in 1999
# Calculating metrics for Cathay Pacific in 2000
# Calculating metrics for Cathay Pacific in 2001
# Calculating metrics for Cathay Pacific in 2002
# Calculating metrics for Cathay Pacific in 2003
# Calculating metrics for Cathay Pacific in 2004
# Calculating metrics for Cathay Pacific in 2005
# Calculating metrics for Cathay Pacific in 2006
# Calculating metrics for Cathay Pacific in 2007
# Calculating metrics for Cathay Pacific in 2008
# Calculating metrics for Cathay Pacific in 2009
# Calculating metrics for Cathay Pacific in 2010
# Calculating metrics for Cathay Pacific in 2011
# Calculating metrics for Chemtura in 1997
# Calculating metrics for Chemtura in 1998
# Calculating metrics for Chemtura in 1999
# Calculating metrics for Chemtura in 2000
# Calculating metrics for Chemtura in 2001
# Calculating metrics for Chemtura in 2002
# Calculating metrics for Chemtura in 2003
# Calculating metrics for Chemtura in 2004
# Calculating metrics for Chemtura in 2005
# Calculating metrics for Chemtura in 2006
# Calculating metrics for Chemtura in 2007
# Calculating metrics for Chemtura in 2008
# Calculating metrics for Chemtura in 2009
# Calculating metrics for Chemtura in 2010
# Calculating metrics for Chimei in 1997
# Calculating metrics for Chimei in 1998
# Calculating metrics for Chimei in 1999
# Calculating metrics for Chimei in 2000
# Calculating metrics for Chimei in 2001
# Calculating metrics for Chimei in 2002
# Calculating metrics for Chimei in 2003
# Calculating metrics for Chimei in 2004
# Calculating metrics for Chimei in 2005
# Calculating metrics for Chimei in 2006
# Calculating metrics for Chimei in 2007
# Calculating metrics for Chimei in 2008
# Calculating metrics for Chimei in 2009
# Calculating metrics for Chimei in 2010
# Calculating metrics for Chimei in 2011
# Calculating metrics for chiquita in 1997
# Calculating metrics for chiquita in 1998
# Calculating metrics for chiquita in 1999
# Calculating metrics for chiquita in 2000
# Calculating metrics for chiquita in 2001
# Calculating metrics for chiquita in 2002
# Calculating metrics for chiquita in 2003
# Calculating metrics for chiquita in 2004
# Calculating metrics for chiquita in 2005
# Calculating metrics for chiquita in 2006
# Calculating metrics for chiquita in 2007
# Calculating metrics for chiquita in 2008
# Calculating metrics for chiquita in 2009
# Calculating metrics for chiquita in 2010
# Calculating metrics for chiquita in 2011
# Calculating metrics for Chungwa in 1997
# Calculating metrics for Chungwa in 1998
# Calculating metrics for Chungwa in 1999
# Calculating metrics for Chungwa in 2000
# Calculating metrics for Chungwa in 2001
# Calculating metrics for Chungwa in 2002
# Calculating metrics for Chungwa in 2003
# Calculating metrics for Chungwa in 2004
# Calculating metrics for Chungwa in 2005
# Calculating metrics for Chungwa in 2006
# Calculating metrics for Chungwa in 2007
# Calculating metrics for Chungwa in 2008
# Calculating metrics for Chungwa in 2009
# Calculating metrics for Chungwa in 2010
# Calculating metrics for Chungwa in 2011
# Calculating metrics for Commerzbank in 1997
# Calculating metrics for Commerzbank in 1998
# Calculating metrics for Commerzbank in 1999
# Calculating metrics for Commerzbank in 2000
# Calculating metrics for Commerzbank in 2001
# Calculating metrics for Commerzbank in 2002
# Calculating metrics for Commerzbank in 2003
# Calculating metrics for Commerzbank in 2004
# Calculating metrics for Commerzbank in 2005
# Calculating metrics for Commerzbank in 2006
# Calculating metrics for Commerzbank in 2007
# Calculating metrics for Commerzbank in 2008
# Calculating metrics for Commerzbank in 2009
# Calculating metrics for Commerzbank in 2010
# Calculating metrics for Commerzbank in 2011
# Calculating metrics for del monte in 1997
# Calculating metrics for del monte in 1998
# Calculating metrics for del monte in 1999
# Calculating metrics for del monte in 2000
# Calculating metrics for del monte in 2001
# Calculating metrics for del monte in 2002
# Calculating metrics for del monte in 2003
# Calculating metrics for del monte in 2004
# Calculating metrics for del monte in 2005
# Calculating metrics for del monte in 2006
# Calculating metrics for del monte in 2007
# Calculating metrics for del monte in 2008
# Calculating metrics for del monte in 2009
# Calculating metrics for del monte in 2010
# Calculating metrics for del monte in 2011
# Calculating metrics for Dow in 1997
# Calculating metrics for Dow in 1998
# Calculating metrics for Dow in 1999
# Calculating metrics for Dow in 2000
# Calculating metrics for Dow in 2001
# Calculating metrics for Dow in 2002
# Calculating metrics for Dow in 2003
# Calculating metrics for Dow in 2004
# Calculating metrics for Dow in 2005
# Calculating metrics for Dow in 2006
# Calculating metrics for Dow in 2007
# Calculating metrics for Dow in 2008
# Calculating metrics for Dow in 2009
# Calculating metrics for Dow in 2010
# Calculating metrics for Dow in 2011
# Calculating metrics for Elpida in 1997
# Calculating metrics for Elpida in 1998
# Calculating metrics for Elpida in 1999
# Calculating metrics for Elpida in 2000
# Calculating metrics for Elpida in 2001
# Calculating metrics for Elpida in 2002
# Calculating metrics for Elpida in 2003
# Calculating metrics for Elpida in 2004
# Calculating metrics for Elpida in 2005
# Calculating metrics for Elpida in 2006
# Calculating metrics for Elpida in 2007
# Calculating metrics for Elpida in 2008
# Calculating metrics for Elpida in 2009
# Calculating metrics for Elpida in 2010
# Calculating metrics for Elpida in 2011
# Calculating metrics for ENI in 1997
# Calculating metrics for ENI in 1998
# Calculating metrics for ENI in 1999
# Calculating metrics for ENI in 2000
# Calculating metrics for ENI in 2001
# Calculating metrics for ENI in 2002
# Calculating metrics for ENI in 2003
# Calculating metrics for ENI in 2004
# Calculating metrics for ENI in 2005
# Calculating metrics for ENI in 2006
# Calculating metrics for ENI in 2007
# Calculating metrics for ENI in 2008
# Calculating metrics for ENI in 2009
# Calculating metrics for ENI in 2010
# Calculating metrics for ENI in 2011
# Calculating metrics for EON in 1997
# Calculating metrics for EON in 1998
# Calculating metrics for EON in 1999
# Calculating metrics for EON in 2000
# Calculating metrics for EON in 2001
# Calculating metrics for EON in 2002
# Calculating metrics for EON in 2003
# Calculating metrics for EON in 2004
# Calculating metrics for EON in 2005
# Calculating metrics for EON in 2006
# Calculating metrics for EON in 2007
# Calculating metrics for EON in 2008
# Calculating metrics for EON in 2009
# Calculating metrics for EON in 2010
# Calculating metrics for EON in 2011
# Calculating metrics for Exxon Mobil in 1997
# Calculating metrics for Exxon Mobil in 1998
# Calculating metrics for Exxon Mobil in 1999
# Calculating metrics for Exxon Mobil in 2000
# Calculating metrics for Exxon Mobil in 2001
# Calculating metrics for Exxon Mobil in 2002
# Calculating metrics for Exxon Mobil in 2003
# Calculating metrics for Exxon Mobil in 2004
# Calculating metrics for Exxon Mobil in 2005
# Calculating metrics for Exxon Mobil in 2006
# Calculating metrics for Exxon Mobil in 2007
# Calculating metrics for Exxon Mobil in 2008
# Calculating metrics for Exxon Mobil in 2009
# Calculating metrics for Exxon Mobil in 2010
# Calculating metrics for Exxon Mobil in 2011
# Calculating metrics for Fuji Electric in 1997
# Calculating metrics for Fuji Electric in 1998
# Calculating metrics for Fuji Electric in 1999
# Calculating metrics for Fuji Electric in 2000
# Calculating metrics for Fuji Electric in 2001
# Calculating metrics for Fuji Electric in 2002
# Calculating metrics for Fuji Electric in 2003
# Calculating metrics for Fuji Electric in 2004
# Calculating metrics for Fuji Electric in 2005
# Calculating metrics for Fuji Electric in 2006
# Calculating metrics for Fuji Electric in 2007
# Calculating metrics for Fuji Electric in 2008
# Calculating metrics for Fuji Electric in 2009
# Calculating metrics for Fuji Electric in 2010
# Calculating metrics for Fuji Electric in 2011
# Calculating metrics for Fujifilm in 1997
# Calculating metrics for Fujifilm in 1998
# Calculating metrics for Fujifilm in 1999
# Calculating metrics for Fujifilm in 2000
# Calculating metrics for Fujifilm in 2001
# Calculating metrics for Fujifilm in 2002
# Calculating metrics for Fujifilm in 2003
# Calculating metrics for Fujifilm in 2004
# Calculating metrics for Fujifilm in 2005
# Calculating metrics for Fujifilm in 2006
# Calculating metrics for Fujifilm in 2007
# Calculating metrics for Fujifilm in 2008
# Calculating metrics for Fujifilm in 2009
# Calculating metrics for Fujifilm in 2010
# Calculating metrics for Fujifilm in 2011
# Calculating metrics for GDF suez in 1997
# Calculating metrics for GDF suez in 1998
# Calculating metrics for GDF suez in 1999
# Calculating metrics for GDF suez in 2000
# Calculating metrics for GDF suez in 2001
# Calculating metrics for GDF suez in 2002
# Calculating metrics for GDF suez in 2003
# Calculating metrics for GDF suez in 2004
# Calculating metrics for GDF suez in 2005
# Calculating metrics for GDF suez in 2006
# Calculating metrics for GDF suez in 2007
# Calculating metrics for GDF suez in 2008
# Calculating metrics for GDF suez in 2009
# Calculating metrics for GDF suez in 2010
# Calculating metrics for GDF suez in 2011
# Calculating metrics for Hannstar Display in 1997
# Calculating metrics for Hannstar Display in 1998
# Calculating metrics for Hannstar Display in 1999
# Calculating metrics for Hannstar Display in 2000
# Calculating metrics for Hannstar Display in 2001
# Calculating metrics for Hannstar Display in 2002
# Calculating metrics for Hannstar Display in 2003
# Calculating metrics for Hannstar Display in 2004
# Calculating metrics for Hannstar Display in 2005
# Calculating metrics for Hannstar Display in 2006
# Calculating metrics for Hannstar Display in 2007
# Calculating metrics for Hannstar Display in 2008
# Calculating metrics for Hannstar Display in 2009
# Calculating metrics for Hannstar Display in 2010
# Calculating metrics for Hannstar Display in 2011
# Calculating metrics for Henkel in 1997
# Calculating metrics for Henkel in 1998
# Calculating metrics for Henkel in 1999
# Calculating metrics for Henkel in 2000
# Calculating metrics for Henkel in 2001
# Calculating metrics for Henkel in 2002
# Calculating metrics for Henkel in 2003
# Calculating metrics for Henkel in 2004
# Calculating metrics for Henkel in 2005
# Calculating metrics for Henkel in 2006
# Calculating metrics for Henkel in 2007
# Calculating metrics for Henkel in 2008
# Calculating metrics for Henkel in 2009
# Calculating metrics for Henkel in 2010
# Calculating metrics for Henkel in 2011
# Calculating metrics for hitachi ltd in 1997
# Calculating metrics for hitachi ltd in 1998
# Calculating metrics for hitachi ltd in 1999
# Calculating metrics for hitachi ltd in 2000
# Calculating metrics for hitachi ltd in 2001
# Calculating metrics for hitachi ltd in 2002
# Calculating metrics for hitachi ltd in 2003
# Calculating metrics for hitachi ltd in 2004
# Calculating metrics for hitachi ltd in 2005
# Calculating metrics for hitachi ltd in 2006
# Calculating metrics for hitachi ltd in 2007
# Calculating metrics for hitachi ltd in 2008
# Calculating metrics for hitachi ltd in 2009
# Calculating metrics for hitachi ltd in 2010
# Calculating metrics for hitachi ltd in 2011
# Calculating metrics for Hitachi Maxell in 1997
# Calculating metrics for Hitachi Maxell in 1998
# Calculating metrics for Hitachi Maxell in 1999
# Calculating metrics for Hitachi Maxell in 2000
# Calculating metrics for Hitachi Maxell in 2001
# Calculating metrics for Hitachi Maxell in 2002
# Calculating metrics for Hitachi Maxell in 2003
# Calculating metrics for Hitachi Maxell in 2004
# Calculating metrics for Hitachi Maxell in 2005
# Calculating metrics for Hitachi Maxell in 2006
# Calculating metrics for Hitachi Maxell in 2007
# Calculating metrics for Hitachi Maxell in 2008
# Calculating metrics for Hitachi Maxell in 2009
# Calculating metrics for Hitachi Maxell in 2010
# Calculating metrics for Hitachi Maxell in 2011
# Calculating metrics for ICI in 1997
# Calculating metrics for ICI in 1998
# Calculating metrics for ICI in 1999
# Calculating metrics for ICI in 2000
# Calculating metrics for ICI in 2001
# Calculating metrics for ICI in 2002
# Calculating metrics for ICI in 2003
# Calculating metrics for ICI in 2004
# Calculating metrics for ICI in 2005
# Calculating metrics for ICI in 2006
# Calculating metrics for ICI in 2007
# Calculating metrics for ICI in 2008
# Calculating metrics for ICI in 2009
# Calculating metrics for ICI in 2010
# Calculating metrics for ICI in 2011
# Calculating metrics for IMI PLC in 1997
# Calculating metrics for IMI PLC in 1998
# Calculating metrics for IMI PLC in 1999
# Calculating metrics for IMI PLC in 2000
# Calculating metrics for IMI PLC in 2001
# Calculating metrics for IMI PLC in 2002
# Calculating metrics for IMI PLC in 2003
# Calculating metrics for IMI PLC in 2004
# Calculating metrics for IMI PLC in 2005
# Calculating metrics for IMI PLC in 2006
# Calculating metrics for IMI PLC in 2007
# Calculating metrics for IMI PLC in 2008
# Calculating metrics for IMI PLC in 2009
# Calculating metrics for IMI PLC in 2010
# Calculating metrics for IMI PLC in 2011
# Calculating metrics for Infineon in 1997
# Calculating metrics for Infineon in 1998
# Calculating metrics for Infineon in 1999
# Calculating metrics for Infineon in 2000
# Calculating metrics for Infineon in 2001
# Calculating metrics for Infineon in 2002
# Calculating metrics for Infineon in 2003
# Calculating metrics for Infineon in 2004
# Calculating metrics for Infineon in 2005
# Calculating metrics for Infineon in 2006
# Calculating metrics for Infineon in 2007
# Calculating metrics for Infineon in 2008
# Calculating metrics for Infineon in 2009
# Calculating metrics for Infineon in 2010
# Calculating metrics for Infineon in 2011
# Calculating metrics for LG Display in 1997
# Calculating metrics for LG Display in 1998
# Calculating metrics for LG Display in 1999
# Calculating metrics for LG Display in 2000
# Calculating metrics for LG Display in 2001
# Calculating metrics for LG Display in 2002
# Calculating metrics for LG Display in 2003
# Calculating metrics for LG Display in 2004
# Calculating metrics for LG Display in 2005
# Calculating metrics for LG Display in 2006
# Calculating metrics for LG Display in 2007
# Calculating metrics for LG Display in 2008
# Calculating metrics for LG Display in 2009
# Calculating metrics for LG Display in 2010
# Calculating metrics for LG Display in 2011
# Calculating metrics for Micron in 1997
# Calculating metrics for Micron in 1998
# Calculating metrics for Micron in 1999
# Calculating metrics for Micron in 2000
# Calculating metrics for Micron in 2001
# Calculating metrics for Micron in 2002
# Calculating metrics for Micron in 2003
# Calculating metrics for Micron in 2004
# Calculating metrics for Micron in 2005
# Calculating metrics for Micron in 2006
# Calculating metrics for Micron in 2007
# Calculating metrics for Micron in 2008
# Calculating metrics for Micron in 2009
# Calculating metrics for Micron in 2010
# Calculating metrics for Micron in 2011
# Calculating metrics for Mitsubishi in 1997
# Calculating metrics for Mitsubishi in 1998
# Calculating metrics for Mitsubishi in 1999
# Calculating metrics for Mitsubishi in 2000
# Calculating metrics for Mitsubishi in 2001
# Calculating metrics for Mitsubishi in 2002
# Calculating metrics for Mitsubishi in 2003
# Calculating metrics for Mitsubishi in 2004
# Calculating metrics for Mitsubishi in 2005
# Calculating metrics for Mitsubishi in 2006
# Calculating metrics for Mitsubishi in 2007
# Calculating metrics for Mitsubishi in 2008
# Calculating metrics for Mitsubishi in 2009
# Calculating metrics for Mitsubishi in 2010
# Calculating metrics for Mitsubishi in 2011
# Calculating metrics for Mueller Industries in 1997
# Calculating metrics for Mueller Industries in 1998
# Calculating metrics for Mueller Industries in 1999
# Calculating metrics for Mueller Industries in 2000
# Calculating metrics for Mueller Industries in 2001
# Calculating metrics for Mueller Industries in 2002
# Calculating metrics for Mueller Industries in 2003
# Calculating metrics for Mueller Industries in 2004
# Calculating metrics for Mueller Industries in 2005
# Calculating metrics for Mueller Industries in 2006
# Calculating metrics for Mueller Industries in 2007
# Calculating metrics for Mueller Industries in 2008
# Calculating metrics for Mueller Industries in 2009
# Calculating metrics for Mueller Industries in 2010
# Calculating metrics for Mueller Industries in 2011
# Calculating metrics for Nanya Tech in 1997
# Calculating metrics for Nanya Tech in 1998
# Calculating metrics for Nanya Tech in 1999
# Calculating metrics for Nanya Tech in 2000
# Calculating metrics for Nanya Tech in 2001
# Calculating metrics for Nanya Tech in 2002
# Calculating metrics for Nanya Tech in 2003
# Calculating metrics for Nanya Tech in 2004
# Calculating metrics for Nanya Tech in 2005
# Calculating metrics for Nanya Tech in 2006
# Calculating metrics for Nanya Tech in 2007
# Calculating metrics for Nanya Tech in 2008
# Calculating metrics for Nanya Tech in 2009
# Calculating metrics for Nanya Tech in 2010
# Calculating metrics for Nanya Tech in 2011
# Calculating metrics for NEC in 1997
# Calculating metrics for NEC in 1998
# Calculating metrics for NEC in 1999
# Calculating metrics for NEC in 2000
# Calculating metrics for NEC in 2001
# Calculating metrics for NEC in 2002
# Calculating metrics for NEC in 2003
# Calculating metrics for NEC in 2004
# Calculating metrics for NEC in 2005
# Calculating metrics for NEC in 2006
# Calculating metrics for NEC in 2007
# Calculating metrics for NEC in 2008
# Calculating metrics for NEC in 2009
# Calculating metrics for NEC in 2010
# Calculating metrics for NEC in 2011
# Calculating metrics for Nippon electric glass in 1997
# Calculating metrics for Nippon electric glass in 1998
# Calculating metrics for Nippon electric glass in 1999
# Calculating metrics for Nippon electric glass in 2000
# Calculating metrics for Nippon electric glass in 2001
# Calculating metrics for Nippon electric glass in 2002
# Calculating metrics for Nippon electric glass in 2003
# Calculating metrics for Nippon electric glass in 2004
# Calculating metrics for Nippon electric glass in 2005
# Calculating metrics for Nippon electric glass in 2006
# Calculating metrics for Nippon electric glass in 2007
# Calculating metrics for Nippon electric glass in 2008
# Calculating metrics for Nippon electric glass in 2009
# Calculating metrics for Nippon electric glass in 2010
# Calculating metrics for Nippon electric glass in 2011
# Calculating metrics for Panasonic in 1997
# Calculating metrics for Panasonic in 1998
# Calculating metrics for Panasonic in 1999
# Calculating metrics for Panasonic in 2000
# Calculating metrics for Panasonic in 2001
# Calculating metrics for Panasonic in 2002
# Calculating metrics for Panasonic in 2003
# Calculating metrics for Panasonic in 2004
# Calculating metrics for Panasonic in 2005
# Calculating metrics for Panasonic in 2006
# Calculating metrics for Panasonic in 2007
# Calculating metrics for Panasonic in 2008
# Calculating metrics for Panasonic in 2009
# Calculating metrics for Panasonic in 2010
# Calculating metrics for Panasonic in 2011
# Calculating metrics for Pilkington in 1997
# Calculating metrics for Pilkington in 1998
# Calculating metrics for Pilkington in 1999
# Calculating metrics for Pilkington in 2000
# Calculating metrics for Pilkington in 2001
# Calculating metrics for Pilkington in 2002
# Calculating metrics for Pilkington in 2003
# Calculating metrics for Pilkington in 2004
# Calculating metrics for Pilkington in 2005
# Calculating metrics for Pilkington in 2006
# Calculating metrics for Pilkington in 2007
# Calculating metrics for Pilkington in 2008
# Calculating metrics for Pilkington in 2009
# Calculating metrics for Pilkington in 2010
# Calculating metrics for Pilkington in 2011
# Calculating metrics for procter gamble in 1997
# Calculating metrics for procter gamble in 1998
# Calculating metrics for procter gamble in 1999
# Calculating metrics for procter gamble in 2000
# Calculating metrics for procter gamble in 2001
# Calculating metrics for procter gamble in 2002
# Calculating metrics for procter gamble in 2003
# Calculating metrics for procter gamble in 2004
# Calculating metrics for procter gamble in 2005
# Calculating metrics for procter gamble in 2006
# Calculating metrics for procter gamble in 2007
# Calculating metrics for procter gamble in 2008
# Calculating metrics for procter gamble in 2009
# Calculating metrics for procter gamble in 2010
# Calculating metrics for procter gamble in 2011
# Calculating metrics for Qantas in 1997
# Calculating metrics for Qantas in 1998
# Calculating metrics for Qantas in 1999
# Calculating metrics for Qantas in 2000
# Calculating metrics for Qantas in 2001
# Calculating metrics for Qantas in 2002
# Calculating metrics for Qantas in 2003
# Calculating metrics for Qantas in 2004
# Calculating metrics for Qantas in 2005
# Calculating metrics for Qantas in 2006
# Calculating metrics for Qantas in 2007
# Calculating metrics for Qantas in 2008
# Calculating metrics for Qantas in 2009
# Calculating metrics for Qantas in 2010
# Calculating metrics for Qantas in 2011
# Calculating metrics for rautaruukki in 1997
# Calculating metrics for rautaruukki in 1998
# Calculating metrics for rautaruukki in 1999
# Calculating metrics for rautaruukki in 2000
# Calculating metrics for rautaruukki in 2001
# Calculating metrics for rautaruukki in 2002
# Calculating metrics for rautaruukki in 2003
# Calculating metrics for rautaruukki in 2004
# Calculating metrics for rautaruukki in 2005
# Calculating metrics for rautaruukki in 2006
# Calculating metrics for rautaruukki in 2007
# Calculating metrics for rautaruukki in 2008
# Calculating metrics for rautaruukki in 2009
# Calculating metrics for rautaruukki in 2010
# Calculating metrics for rautaruukki in 2011
# Calculating metrics for Repsol YPF in 1997
# Calculating metrics for Repsol YPF in 1998
# Calculating metrics for Repsol YPF in 1999
# Calculating metrics for Repsol YPF in 2000
# Calculating metrics for Repsol YPF in 2001
# Calculating metrics for Repsol YPF in 2002
# Calculating metrics for Repsol YPF in 2003
# Calculating metrics for Repsol YPF in 2004
# Calculating metrics for Repsol YPF in 2005
# Calculating metrics for Repsol YPF in 2006
# Calculating metrics for Repsol YPF in 2007
# Calculating metrics for Repsol YPF in 2008
# Calculating metrics for Repsol YPF in 2009
# Calculating metrics for Repsol YPF in 2010
# Calculating metrics for Repsol YPF in 2011
# Calculating metrics for samsung in 1997
# Calculating metrics for samsung in 1998
# Calculating metrics for samsung in 1999
# Calculating metrics for samsung in 2000
# Calculating metrics for samsung in 2001
# Calculating metrics for samsung in 2002
# Calculating metrics for samsung in 2003
# Calculating metrics for samsung in 2004
# Calculating metrics for samsung in 2005
# Calculating metrics for samsung in 2006
# Calculating metrics for samsung in 2007
# Calculating metrics for samsung in 2008
# Calculating metrics for samsung in 2009
# Calculating metrics for samsung in 2010
# Calculating metrics for samsung in 2011
# Calculating metrics for SAS AB in 1997
# Calculating metrics for SAS AB in 1998
# Calculating metrics for SAS AB in 1999
# Calculating metrics for SAS AB in 2000
# Calculating metrics for SAS AB in 2001
# Calculating metrics for SAS AB in 2002
# Calculating metrics for SAS AB in 2003
# Calculating metrics for SAS AB in 2004
# Calculating metrics for SAS AB in 2005
# Calculating metrics for SAS AB in 2006
# Calculating metrics for SAS AB in 2007
# Calculating metrics for SAS AB in 2008
# Calculating metrics for SAS AB in 2009
# Calculating metrics for SAS AB in 2010
# Calculating metrics for SAS AB in 2011
# Calculating metrics for Siemens in 1997
# Calculating metrics for Siemens in 1998
# Calculating metrics for Siemens in 1999
# Calculating metrics for Siemens in 2000
# Calculating metrics for Siemens in 2001
# Calculating metrics for Siemens in 2002
# Calculating metrics for Siemens in 2003
# Calculating metrics for Siemens in 2004
# Calculating metrics for Siemens in 2005
# Calculating metrics for Siemens in 2006
# Calculating metrics for Siemens in 2007
# Calculating metrics for Siemens in 2008
# Calculating metrics for Siemens in 2009
# Calculating metrics for Siemens in 2010
# Calculating metrics for Siemens in 2011
# Calculating metrics for Singapore Airlines in 1997
# Calculating metrics for Singapore Airlines in 1998
# Calculating metrics for Singapore Airlines in 1999
# Calculating metrics for Singapore Airlines in 2000
# Calculating metrics for Singapore Airlines in 2001
# Calculating metrics for Singapore Airlines in 2002
# Calculating metrics for Singapore Airlines in 2003
# Calculating metrics for Singapore Airlines in 2004
# Calculating metrics for Singapore Airlines in 2005
# Calculating metrics for Singapore Airlines in 2006
# Calculating metrics for Singapore Airlines in 2007
# Calculating metrics for Singapore Airlines in 2008
# Calculating metrics for Singapore Airlines in 2009
# Calculating metrics for Singapore Airlines in 2010
# Calculating metrics for Singapore Airlines in 2011
# Calculating metrics for SKW Stahl in 1997
# Calculating metrics for SKW Stahl in 1998
# Calculating metrics for SKW Stahl in 1999
# Calculating metrics for SKW Stahl in 2000
# Calculating metrics for SKW Stahl in 2001
# Calculating metrics for SKW Stahl in 2002
# Calculating metrics for SKW Stahl in 2003
# Calculating metrics for SKW Stahl in 2004
# Calculating metrics for SKW Stahl in 2005
# Calculating metrics for SKW Stahl in 2006
# Calculating metrics for SKW Stahl in 2007
# Calculating metrics for SKW Stahl in 2008
# Calculating metrics for SKW Stahl in 2009
# Calculating metrics for SKW Stahl in 2010
# Calculating metrics for SKW Stahl in 2011
# Calculating metrics for Sony in 1997
# Calculating metrics for Sony in 1998
# Calculating metrics for Sony in 1999
# Calculating metrics for Sony in 2000
# Calculating metrics for Sony in 2001
# Calculating metrics for Sony in 2002
# Calculating metrics for Sony in 2003
# Calculating metrics for Sony in 2004
# Calculating metrics for Sony in 2005
# Calculating metrics for Sony in 2006
# Calculating metrics for Sony in 2007
# Calculating metrics for Sony in 2008
# Calculating metrics for Sony in 2009
# Calculating metrics for Sony in 2010
# Calculating metrics for Sony in 2011
# Calculating metrics for Toshiba in 1997
# Calculating metrics for Toshiba in 1998
# Calculating metrics for Toshiba in 1999
# Calculating metrics for Toshiba in 2000
# Calculating metrics for Toshiba in 2001
# Calculating metrics for Toshiba in 2002
# Calculating metrics for Toshiba in 2003
# Calculating metrics for Toshiba in 2004
# Calculating metrics for Toshiba in 2005
# Calculating metrics for Toshiba in 2006
# Calculating metrics for Toshiba in 2007
# Calculating metrics for Toshiba in 2008
# Calculating metrics for Toshiba in 2009
# Calculating metrics for Toshiba in 2010
# Calculating metrics for Toshiba in 2011
# Calculating metrics for Total in 1997
# Calculating metrics for Total in 1998
# Calculating metrics for Total in 1999
# Calculating metrics for Total in 2000
# Calculating metrics for Total in 2001
# Calculating metrics for Total in 2002
# Calculating metrics for Total in 2003
# Calculating metrics for Total in 2004
# Calculating metrics for Total in 2005
# Calculating metrics for Total in 2006
# Calculating metrics for Total in 2007
# Calculating metrics for Total in 2008
# Calculating metrics for Total in 2009
# Calculating metrics for Total in 2010
# Calculating metrics for Total in 2011
# Calculating metrics for Unilever NV in 1997
# Calculating metrics for Unilever NV in 1998
# Calculating metrics for Unilever NV in 1999
# Calculating metrics for Unilever NV in 2000
# Calculating metrics for Unilever NV in 2001
# Calculating metrics for Unilever NV in 2002
# Calculating metrics for Unilever NV in 2003
# Calculating metrics for Unilever NV in 2004
# Calculating metrics for Unilever NV in 2005
# Calculating metrics for Unilever NV in 2006
# Calculating metrics for Unilever NV in 2007
# Calculating metrics for Unilever NV in 2008
# Calculating metrics for Unilever NV in 2009
# Calculating metrics for Unilever NV in 2010
# Calculating metrics for Unilever NV in 2011
# Calculating metrics for Unilever PLC in 1997
# Calculating metrics for Unilever PLC in 1998
# Calculating metrics for Unilever PLC in 1999
# Calculating metrics for Unilever PLC in 2000
# Calculating metrics for Unilever PLC in 2001
# Calculating metrics for Unilever PLC in 2002
# Calculating metrics for Unilever PLC in 2003
# Calculating metrics for Unilever PLC in 2004
# Calculating metrics for Unilever PLC in 2005
# Calculating metrics for Unilever PLC in 2006
# Calculating metrics for Unilever PLC in 2007
# Calculating metrics for Unilever PLC in 2008
# Calculating metrics for Unilever PLC in 2009
# Calculating metrics for Unilever PLC in 2010
# Calculating metrics for Unilever PLC in 2011
# Calculating metrics for Unipetrol in 1997
# Calculating metrics for Unipetrol in 1998
# Calculating metrics for Unipetrol in 1999
# Calculating metrics for Unipetrol in 2000
# Calculating metrics for Unipetrol in 2001
# Calculating metrics for Unipetrol in 2002
# Calculating metrics for Unipetrol in 2003
# Calculating metrics for Unipetrol in 2004
# Calculating metrics for Unipetrol in 2005
# Calculating metrics for Unipetrol in 2006
# Calculating metrics for Unipetrol in 2007
# Calculating metrics for Unipetrol in 2008
# Calculating metrics for Unipetrol in 2009
# Calculating metrics for Unipetrol in 2010
# Calculating metrics for Unipetrol in 2011
# Calculating metrics for United technologies corp in 1997
# Calculating metrics for United technologies corp in 1998
# Calculating metrics for United technologies corp in 1999
# Calculating metrics for United technologies corp in 2000
# Calculating metrics for United technologies corp in 2001
# Calculating metrics for United technologies corp in 2002
# Calculating metrics for United technologies corp in 2003
# Calculating metrics for United technologies corp in 2004
# Calculating metrics for United technologies corp in 2005
# Calculating metrics for United technologies corp in 2006
# Calculating metrics for United technologies corp in 2007
# Calculating metrics for United technologies corp in 2008
# Calculating metrics for United technologies corp in 2009
# Calculating metrics for United technologies corp in 2010
# Calculating metrics for United technologies corp in 2011
# Calculating metrics for Uralita in 1997
# Calculating metrics for Uralita in 1998
# Calculating metrics for Uralita in 1999
# Calculating metrics for Uralita in 2000
# Calculating metrics for Uralita in 2001
# Calculating metrics for Uralita in 2002
# Calculating metrics for Uralita in 2003
# Calculating metrics for Uralita in 2004
# Calculating metrics for Uralita in 2005
# Calculating metrics for Uralita in 2006
# Calculating metrics for Uralita in 2007
# Calculating metrics for Uralita in 2008
# Calculating metrics for Uralita in 2009
# Calculating metrics for Uralita in 2010
# Calculating metrics for Uralita in 2011
# Calculating metrics for Whirlpool in 1997
# Calculating metrics for Whirlpool in 1998
# Calculating metrics for Whirlpool in 1999
# Calculating metrics for Whirlpool in 2000
# Calculating metrics for Whirlpool in 2001
# Calculating metrics for Whirlpool in 2002
# Calculating metrics for Whirlpool in 2003
# Calculating metrics for Whirlpool in 2004
# Calculating metrics for Whirlpool in 2005
# Calculating metrics for Whirlpool in 2006
# Calculating metrics for Whirlpool in 2007
# Calculating metrics for Whirlpool in 2008
# Calculating metrics for Whirlpool in 2009
# Calculating metrics for Whirlpool in 2010
# Calculating metrics for Whirlpool in 2011
# Calculating metrics for Zeon in 1997
# Calculating metrics for Zeon in 1998
# Calculating metrics for Zeon in 1999
# Calculating metrics for Zeon in 2000
# Calculating metrics for Zeon in 2001
# Calculating metrics for Zeon in 2002
# Calculating metrics for Zeon in 2003
# Calculating metrics for Zeon in 2004
# Calculating metrics for Zeon in 2005
# Calculating metrics for Zeon in 2006
# Calculating metrics for Zeon in 2007
# Calculating metrics for Zeon in 2008
# Calculating metrics for Zeon in 2009
# Calculating metrics for Zeon in 2010
# Calculating metrics for Zeon in 2011

# %%
# List for the top investors
top_investors_list = []

for sh_df in shareholder_dfs:
    # Get all columns with perc_os in the name
    perc_os_columns = sh_df.columns[sh_df.columns.str.contains('perc_os')]

    # Convert all perc_os columns to numeric
    sh_df[perc_os_columns] = sh_df[perc_os_columns].apply(pd.to_numeric, errors='coerce')

    # Get the name of the company e.g. ABB (Take 0 index because we only have one company per file -> its the same for all rows)
    company_name = sh_df["company_name"][0]

    for column in perc_os_columns:
        year = column[-4:]

        # Get top 5 investors for the column
        top5 = df.nlargest(5, column)[["investor_name", column]].reset_index(drop=True)

        for rank in range(5):
            try:
                investor = top5.loc[rank, "investor_name"]
                perc = top5.loc[rank, column]

                if pd.isna(perc):
                    continue  # If no value is available, skip this investor

                # Result dictionary
                result = {
                    "company_name": company_name,
                    "year": int(year),
                    "rank": rank + 1,
                    "investor_name": investor,
                    "perc_os": perc
                }

                # Append to the list
                top_investors_list.append(result)

            except IndexError:
                # less than 5 investors
                continue

# Transform the list into a DataFrame
top_investors_df = pd.DataFrame(top_investors_list)

# Sort the DataFrame by company_name, year, and rank
top_investors_df = top_investors_df.sort_values(by=["company_name", "year", "rank"])

top_investors_df.to_excel("transformed_data/shareholder_data/top_investors.xlsx", index=False)
